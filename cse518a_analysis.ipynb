# %%
import pandas as pd

# %%
names = ['Size','Reward','Length','Horizon','cost','loss','Accuracy','auc']
df = pd.read_csv('../results_exp1.csv', sep='\t', names=names, index_col=False)
df
# Out:
#      Size  Rewares  Length  Horizon  cost      loss  Accuracy       auc
# 0       6        2       5        1     0  0.016226  0.994100  0.999616
# 1       6        2       5        1     5  0.022038  0.992175  0.999864
# 2       6        2       5        1    10  0.014380  0.994975  0.999840
# 3       6        2       5        2     0  0.089071  0.971175  0.991851
# 4       6        2       5        2     5  0.074839  0.977975  0.993335
# ..    ...      ...     ...      ...   ...       ...       ...       ...
# 319     8        5       8        2     5  0.135463  0.954450  0.984624
# 320     8        5       8        2    10  0.137117  0.959425  0.984803
# 321     8        5       8        3     0  0.241169  0.907275  0.962405
# 322     8        5       8        3     5  0.223525  0.914850  0.967879
# 323     8        5       8        3    10  0.200124  0.927100  0.973477
#
# [324 rows x 8 columns]

# %%
df.groupby('Size').mean().filter(['Accuracy'])
# Out:
#       Accuracy
# Size
# 6     0.958656
# 7     0.960574
# 8     0.966710

# %%
df.groupby('Size').mean().filter(['Accuracy']).plot.bar()
# Out:
# <AxesSubplot:xlabel='Size'>

# %%
df.groupby('Length').mean().filter(['Accuracy'])
# Out:
#         Accuracy
# Length
# 5       0.969299
# 6       0.962912
# 7       0.959688
# 8       0.956021

# %%
df.groupby('Length').mean().filter(['Accuracy']).plot.bar()
# Out:
# <AxesSubplot:xlabel='Length'>

# %%
df.groupby('Horizon').mean().filter(['Accuracy'])
# Out:
#          Accuracy
# Horizon
# 1        0.988588
# 2        0.961159
# 3        0.936194

# %%
df.groupby('Horizon').mean().filter(['Accuracy']).plot.bar()
# Out:
# <AxesSubplot:xlabel='Horizon'>

# %%
names = ['size','cost','Training Horizon','Eval Horizon','Accuracy']
df2 = pd.read_csv('../results_exp1_mixed.csv', sep='\t', names=names, index_col=False)
df2
# Out:
#      size  cost  Training Horizon  Eval Horizon  Accuracy
# 0       5     0                 1             1  0.985625
# 1       5     0                 1             2  0.266450
# 2       5     0                 1             3  0.316525
# 3       5     0                 2             1  0.269550
# 4       5     0                 2             2  0.944175
# ..    ...   ...               ...           ...       ...
# 103     8    10                 2             2  0.953400
# 104     8    10                 2             3  0.393450
# 105     8    10                 3             1  0.364825
# 106     8    10                 3             2  0.454575
# 107     8    10                 3             3  0.922800
#
# [108 rows x 5 columns]

# %%
df2.groupby(['Training Horizon', 'Eval Horizon']).mean().filter(['Accuracy'])
# Out:
#                                Accuracy
# Training Horizon Eval Horizon
# 1                1             0.986006
#                  2             0.294035
#                  3             0.331735
# 2                1             0.288552
#                  2             0.949896
#                  3             0.409444
# 3                1             0.370615
#                  2             0.447233
#                  3             0.922033

# %%
names = ['size','cost','Training Horizon','Eval Horizon','Accuracy']
df3 = pd.read_csv('../results_exp2_mixed.csv', sep='\t', names=names, index_col=False)
df3
# Out:
#     size  cost  Training Horizon  Eval Horizon  Accuracy
# 0      5     0                 1             1    0.8930
# 1      5     0                 1             2    0.5645
# 2      5     0                 1             3    0.5200
# 3      5     0                 2             1    0.6045
# 4      5     0                 2             2    0.8365
# ..   ...   ...               ...           ...       ...
# 94     5    10                 2             2    0.9215
# 95     5    10                 2             3    0.4455
# 96     5    10                 3             1    0.4830
# 97     5    10                 3             2    0.6725
# 98     5    10                 3             3    0.8320
#
# [99 rows x 5 columns]

# %%
df3.groupby(['cost']).mean().filter(['Accuracy'])
# Out:
#       Accuracy
# cost
# 0     0.663889
# 1     0.663500
# 2     0.643333
# 3     0.656556
# 4     0.606278
# 5     0.601667
# 6     0.593056
# 7     0.616111
# 8     0.596778
# 9     0.600611
# 10    0.594167

# %%
df3.groupby(['Training Horizon', 'Eval Horizon']).mean().filter(['Accuracy'])
# Out:
#                                Accuracy
# Training Horizon Eval Horizon
# 1                1             0.897091
#                  2             0.498182
#                  3             0.323182
# 2                1             0.548636
#                  2             0.868045
#                  3             0.569818
# 3                1             0.420864
#                  2             0.599409
#                  3             0.867818
